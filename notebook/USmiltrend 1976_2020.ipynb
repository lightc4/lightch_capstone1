# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('../data/Mil_app_acc_76_20.csv')

# %%
df.head()
# Out:
#    Fiscal Year(FY)  Newly Enlisted  Applicants
# 0             1976          393362      609054
# 1             1977          495109      762086
# 2             1978          305644      585820
# 3             1979          310679      609361
# 4             1980          360745      768532

# %%
#https://www.geeksforgeeks.org/plot-multiple-lines-in-matplotlib/
#https://www.geeksforgeeks.org/how-to-set-x-axis-values-in-matplotlib-in-python/
#https://www.geeksforgeeks.org/how-to-change-line-color-in-matplotlib/
x = [1976, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020]
plt.figure(figsize=(10,6))
plt.tick_params(left = False) 
plt.plot(df['Fiscal Year(FY)'], df['Applicants'], label = 'Applicants', color = 'blue')
plt.plot(df['Fiscal Year(FY)'], df['Newly Enlisted'], label = 'Enlisted', color = 'red')

plt.ylim(100000, 900000)

plt.title('Number of Applicants vs People Enlisting in the US Armed Forces, 1976-2020')
plt.xticks(x, rotation=45)
plt.legend()
plt.show()

# %%
#From 1948 until 1973, during both peacetime and periods of conflict,
#men were drafted to fill vacancies in the armed forces which could not be filled through voluntary means. 
#Induction authority expired in 1973, but the Selective Service System remained in existence in “standby” to support 
#the all-volunteer force in case of an emergency. 
#Registration was suspended early in 1975 and the Selective Service System entered into “deep standby”.
#https://www.sss.gov/history-and-records/

# %%
x = [1976, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020]
plt.figure(figsize=(10,6))
plt.tick_params(left = False, bottom = False) 
plt.plot(df['Fiscal Year(FY)'], df['Applicants'], label = 'Applicants', color = 'blue')
plt.plot(df['Fiscal Year(FY)'], df['Newly Enlisted'], label = 'Enlisted', color = 'red')

plt.ylim(100000, 900000)
plt.xlabel('Year (FY)')
plt.ylabel('Numbers of People')
#plt.title('Number of Applicants vs People Enlisting in the US Armed Forces, 1976-2020')
plt.xticks(x, rotation=45)
plt.legend()
plt.show()
