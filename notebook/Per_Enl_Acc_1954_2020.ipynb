# %% [markdown]
# PROJECT QUESTION 1

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

# %% [markdown]
# READ IN FILE

# %%
df = pd.read_excel('../data/Accessions_1954_2020_Age18.xlsx')

# %%
df
# Out:
#     Year  Males_18  Females_18  DoD_Enlist  DoDEnl_Per_of_Civ
# 0   1954      1075        1060         576              26.98
# 1   1955      1074        1068         623              29.08
# 2   1956      1132        1113         482              21.47
# 3   1957      1148        1126         457              20.10
# 4   1958      1164        1143         367              15.91
# ..   ...       ...         ...         ...                ...
# 62  2016      2094        2036         145               3.52
# 63  2017      2088        2000         151               3.70
# 64  2018      2066        2025         164               4.00
# 65  2019      2137        2050         164               3.91
# 66  2020      2050        1969         148               3.69
#
# [67 rows x 5 columns]

# %%
#https://www.geeksforgeeks.org/how-to-remove-ticks-from-matplotlib-plots/

# %%
print('Line graph:')
x = [1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020]
plt.figure(figsize=(10,6))
plt.tick_params(left = False) 
plt.xticks(x, rotation=45)
plt.plot(df['Year'], df['DoDEnl_Per_of_Civ'])
plt.ylim(0, 35)

plt.xlabel('Year')
plt.ylabel('Enlisted Percent (%)')
plt.title('Percent Enlisted Accessions US Armed Forces, Age 18 Only, 1954-2020')
plt.show()
# Out:
# Line graph:

# %%
#https://www.cna.org/pop-rep/2019/appendixd/d_01.html
#Accessions reported for 1954-1963 include males only; including females would increase accessions by less than 2 percent.	
#Source: Military data are provided by the Defense Manpower Data Center (DMDC).  Civilian data prior to 1989 represent calendar year. 
#The data incidates a general decline in enlisted accessions across 6 decades.  The increase from the mid 1960s to 1970 was due to the Vietnam Conflict. 
#I found anecdotal evidence that volunteer enlistment did increase among Black and Latino men, due in part to policies designed to attract recruits, 
#such as equal access to the benefits of the GI bill at local levels and the 1966 Veterans Readjustment Benefits Act, 
#which provided education benefits, home and farm loans, employment counseling and placement services for Vietnam Veterans.

# %%
print('Line graph:')
x = [1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020]
plt.figure(figsize=(10,6))
plt.tick_params(left = False, bottom = False) 
plt.xticks(x, rotation=45)
plt.plot(df['Year'], df['DoDEnl_Per_of_Civ'])
plt.ylim(0, 35)

plt.xlabel('Year (FY)')
plt.ylabel('Enlisted Percent (%)')

plt.show()
# Out:
# Line graph:
